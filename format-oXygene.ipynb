# %% [markdown]
# # Formater les textes pour oXygene

# %% [markdown]
# ## Fonction pour les lignes

# %%
import re

def remplacer_lignes(text):
    i = 0
    def incrementer(match):
        nonlocal i
        i += 1
        return f'\n<lb n="{i}"/>'
    
    return re.sub(r'/', incrementer, text)

# %%
print(remplacer_lignes("Ceci est un test / pour voir si les lignes sont remplacées / correctement"))
# Out:
# Ceci est un test
# <lb n="1"/> pour voir si les lignes sont remplacées
# <lb n="2"/> correctement
